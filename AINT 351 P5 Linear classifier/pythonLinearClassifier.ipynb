# %%
import numpy as np
import matplotlib.pyplot as plt
from GenerateGaussianData import GenerateGaussianData
from numpy import random
samples = 1000
mean1 = np.matrix('3; -1')
mean2 = np.matrix('-3;-1')
sigma1 = np.matrix('0.5 0.95; 0.95 4')
sigma2 = np.matrix('0.5 0.95; 0.95 4')

# %% [markdown]
# ## Task 1

# %%
testing1, target1 = GenerateGaussianData(samples, mean1, sigma1, mean2, sigma2)
testing2, target2 = GenerateGaussianData(samples, mean1, sigma1, mean2, sigma2)
fidx = np.where(target1[0,:] == 1)
c1data = testing1[:,fidx[1]]
fidy = np.where(target2[0,:] == 0)
c2data = testing2[:,fidy[1]]
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter([c1data[0,:]], [c1data[1,:]], c='b', marker="s")
ax1.scatter([c2data[0,:]], [c2data[1,:]], c='r', marker="o")

# %% [markdown]
# ## Task 2

# %%
dataSet1 = 20*random.rand(2,samples) -10
fig2 = plt.figure()
ax12 = fig2.add_subplot(111)
ax12.scatter([dataSet1[0,:]],[dataSet1[1,:]], c = 'g', marker = '*')

# %% [markdown]
# ## Task 3
#
# * $ O = WX $
#     * append 1 to x to allow for multiply with bias

# %% [markdown]
# ## Task 4
# * individualError $ ei = (Xi - Ti)^2 $
# * totalError (cost function) $ e = [X-T]'[X-T] $

# %% [markdown]
# ## Task 5
#
# * $ \frac{\partial e} {\partial W} = - (t - O) X^{T} $

# %% [markdown]
# ## Task 6
#
# * $ W := W - \alpha \frac{de}{dW} $
#     * where $ \alpha $ is the learning rate

# %% [markdown]
# ## Task7

# %%
from Functions import Trainer
weight, output, error = Trainer(testing1, target1[1,:])
print(weight)
fig = plt.figure()
ax1 = fig.add_subplot(111)
print(np.arange(np.size(output,1)).shape)
ax1.scatter(output[0,:], np.arange(np.size(output,1)), c='b', marker="s")
# Out:
# [[ 1.53561823  1.00822661 -0.85713971]]
# (2000,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-a31a0eb4e7c4> in <module>
#       5 ax1 = fig.add_subplot(111)
#       6 print(np.arange(np.size(output,1)).shape)
# ----> 7 ax1.scatter(output[0,:], np.arange(np.size(output,1)), c='b', marker="s")
#
# c:\users\nicholas\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
